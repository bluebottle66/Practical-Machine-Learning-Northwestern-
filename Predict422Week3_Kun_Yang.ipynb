# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bluebottle66/Practical-Machine-Learning-Northwestern-/blob/master/Predict422Week3_Kun_Yang.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
RANDOM_SEED = 1
SET_FIT_INTERCEPT = True

# %%
import sklearn.linear_model
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt # for root mean-squared error calculation

# %% [markdown]
# **Read and Process data**
#
#
#
# 1.   Switch to github link to store csv files
# 2.   Look at data statistics, drop n/a, drop neighborhood
# 3.   Create a new response variable for Log median value of homes in thousands of 1970 dollars
# 4.   Create preliminary dataset
# 5.   Perform Standard Scaler of original data

# %%
url="https://raw.githubusercontent.com/bluebottle66/Practical-Machine-Learning-Northwestern-/master/boston.csv"
boston_input = pd.read_csv(url)

# %%
print('\nboston DataFrame (first and last five rows):')
print(boston_input.head())
print(boston_input.tail())
print('\nGeneral description of the boston_input DataFrame:')
print(boston_input.info())
# Out:
# boston DataFrame (first and last five rows):
#   neighborhood     crim    zn  indus  chas    nox  rooms   age     dis  rad  \
# 0       Nahant  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1   Swampscott  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2   Swanpscott  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3   Marblehead  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4   Marblehead  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat    mv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2
#     neighborhood     crim   zn  indus  chas    nox  rooms   age     dis  rad  \
# 501     Winthrop  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502     Winthrop  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503     Winthrop  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504     Winthrop  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505     Winthrop  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat    mv
# 501  273     21.0   9.67  22.4
# 502  273     21.0   9.08  20.6
# 503  273     21.0   5.64  23.9
# 504  273     21.0   6.48  22.0
# 505  273     21.0   7.88  19.0
#
# General description of the boston_input DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# neighborhood    506 non-null object
# crim            506 non-null float64
# zn              506 non-null float64
# indus           506 non-null float64
# chas            506 non-null int64
# nox             506 non-null float64
# rooms           506 non-null float64
# age             506 non-null float64
# dis             506 non-null float64
# rad             506 non-null int64
# tax             506 non-null int64
# ptratio         506 non-null float64
# lstat           506 non-null float64
# mv              506 non-null float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 55.4+ KB
# None

# %%
print(boston_input.describe())
print(boston_input.columns)
# Out:
#              crim          zn       indus        chas         nox       rooms  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# std     28.148861    2.105710    8.707259  168.537116    2.164946    7.141062
# min      2.900000    1.129600    1.000000  187.000000   12.600000    1.730000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000    6.950000
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000   11.360000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000   16.955000
# max    100.000000   12.126500   24.000000  711.000000   22.000000   37.970000
#
#                mv
# count  506.000000
# mean    22.528854
# std      9.182176
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000
# Index(['neighborhood', 'crim', 'zn', 'indus', 'chas', 'nox', 'rooms', 'age',
#        'dis', 'rad', 'tax', 'ptratio', 'lstat', 'mv'],
#       dtype='object')

# %%
boston = boston_input.drop('neighborhood', 1)

boston.dropna()

#create log transformation for response variable
boston['logMv']=np.log(boston['mv'])

prelim_model_data = np.array([boston.mv,\
boston.logMv,\
boston.crim,\
boston.zn,\
boston.indus,\
boston.chas,\
boston.nox,\
boston.rooms,\
boston.age,\
boston.dis,\
boston.rad,\
boston.tax,\
boston.ptratio,\
boston.lstat]).T

# dimensions of the polynomial model X input and y response
# preliminary data before standardization
print('\nData dimensions:', prelim_model_data.shape)
# Out:
# Data dimensions: (506, 14)

# %%
#Data transformation
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
print(scaler.fit(prelim_model_data))

# show standardization constants being employed
print(scaler.mean_)
print(scaler.scale_)

# the model data will be standardized form of preliminary model data
model_data = scaler.fit_transform(prelim_model_data)

# dimensions of the polynomial model X input and y response
# all in standardized units of measure
print('\nDimensions for model_data:', model_data.shape)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [2.25288538e+01 3.03455800e+00 3.61352356e+00 1.13636364e+01
#  1.11367787e+01 6.91699605e-02 5.54695059e-01 6.28463439e+00
#  6.85749012e+01 3.79504269e+00 9.54940711e+00 4.08237154e+02
#  1.84555336e+01 1.26530632e+01]
# [9.17309810e+00 4.07871084e-01 8.59304135e+00 2.32993957e+01
#  6.85357058e+00 2.53742935e-01 1.15763115e-01 7.01922514e-01
#  2.81210326e+01 2.10362836e+00 8.69865112e+00 1.68370495e+02
#  2.16280519e+00 7.13400164e+00]
#
# Dimensions for model_data: (506, 14)

# %% [markdown]
# **Model Build up and Data Analysis:**
#
#
# *   Look at correlation matrix
# *   Build up 4 regression models (linear, ridge, lasso and elastic net) on both response variables (home value, with its log transform)
# *   Evaluate with cross-validation

# %%
corr=boston.corr()
print(corr[(corr>0.5)|(corr<-0.5)])
# Out:
#              crim        zn     indus  chas       nox     rooms       age  \
# crim     1.000000       NaN       NaN   NaN       NaN       NaN       NaN
# zn            NaN  1.000000 -0.533828   NaN -0.516604       NaN -0.569537
# indus         NaN -0.533828  1.000000   NaN  0.763651       NaN  0.644779
# chas          NaN       NaN       NaN   1.0       NaN       NaN       NaN
# nox           NaN -0.516604  0.763651   NaN  1.000000       NaN  0.731470
# rooms         NaN       NaN       NaN   NaN       NaN  1.000000       NaN
# age           NaN -0.569537  0.644779   NaN  0.731470       NaN  1.000000
# dis           NaN  0.664408 -0.708027   NaN -0.769230       NaN -0.747881
# rad      0.625505       NaN  0.595129   NaN  0.611441       NaN       NaN
# tax      0.582764       NaN  0.720760   NaN  0.668023       NaN  0.506456
# ptratio       NaN       NaN       NaN   NaN       NaN       NaN       NaN
# lstat         NaN       NaN  0.603800   NaN  0.590879 -0.613808  0.602339
# mv            NaN       NaN       NaN   NaN       NaN  0.696304       NaN
# logMv   -0.530001       NaN -0.543195   NaN -0.513431  0.632536       NaN
#
#               dis       rad       tax   ptratio     lstat        mv     logMv
# crim          NaN  0.625505  0.582764       NaN       NaN       NaN -0.530001
# zn       0.664408       NaN       NaN       NaN       NaN       NaN       NaN
# indus   -0.708027  0.595129  0.720760       NaN  0.603800       NaN -0.543195
# chas          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# nox     -0.769230  0.611441  0.668023       NaN  0.590879       NaN -0.513431
# rooms         NaN       NaN       NaN       NaN -0.613808  0.696304  0.632536
# age     -0.747881       NaN  0.506456       NaN  0.602339       NaN       NaN
# dis      1.000000       NaN -0.534432       NaN       NaN       NaN       NaN
# rad           NaN  1.000000  0.910228       NaN       NaN       NaN       NaN
# tax     -0.534432  0.910228  1.000000       NaN  0.543993       NaN -0.566214
# ptratio       NaN       NaN       NaN  1.000000       NaN -0.505655       NaN
# lstat         NaN       NaN  0.543993       NaN  1.000000 -0.740836 -0.809234
# mv            NaN       NaN       NaN -0.505655 -0.740836  1.000000  0.952967
# logMv         NaN       NaN -0.566214       NaN -0.809234  0.952967  1.000000

# %% [markdown]
# Only look at the basic correlation with larger than 0.5 or smaller than -0.5: we can find:
#
# positive correlation: rooms
#
# negative correlation: crim, indus, nox,tax,lstat

# %%
#Create list of regression models and all factors in our regression model

names = ['Linear_Regression', 'Ridge_Regression','Lasso_Regression','Elastic_Net_Regression']
variables=['crim','zn','indus','chas','nox','romms','age','dis','rad','tax','ptratio','lstat']

# %%
#Create regressors
regressors = [LinearRegression(fit_intercept = SET_FIT_INTERCEPT),
              Ridge(alpha = 1, solver = 'cholesky',
                fit_intercept = SET_FIT_INTERCEPT,
                normalize = False,
                random_state = RANDOM_SEED),
              Lasso(alpha = 0.1, max_iter=10000, tol=0.01,
                fit_intercept = SET_FIT_INTERCEPT,
                random_state = RANDOM_SEED),
              ElasticNet(alpha = 0.1, l1_ratio = 0.5,
                max_iter=10000, tol=0.01,
                fit_intercept = SET_FIT_INTERCEPT,
                normalize = False,
                random_state = RANDOM_SEED)]

# %% [markdown]
# **Note: below I am using log transform of response variable to build up regression models. I actually tried both raw repsonse variable and log transformed response variable for test. The models using log transform has smaller RMSE as prediction error.**

# %%
N_FOLDS = 10
N_Variables=12

# set up numpy array for storing results

cv_results = np.zeros((N_FOLDS, len(names)))
rsquare_results = np.zeros((N_FOLDS, len(names)))
intercept_results = np.zeros((N_FOLDS, len(names)))
coef_results = np.zeros((N_FOLDS, N_Variables, len(names)))

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = N_FOLDS, shuffle=False, random_state = RANDOM_SEED)
# check the splitting process by looking at fold observation counts
index_for_fold = 0 # fold count initialized

# %%
for train_index, test_index in kf.split(model_data):
  
  print('\nFold index:', index_for_fold,
  '------------------------------------------')

  X_train = model_data[train_index, 2:model_data.shape[1]]
  X_test = model_data[test_index, 2:model_data.shape[1]]
  y_train = model_data[train_index, 1]
  y_test = model_data[test_index, 1]
  # note, if using raw response variable, we shalll use model_data[train_index, 0] here

  print('\nShape of input data for this fold:',
        '\nData Set: (Observations, Variables)')
  print('X_train:', X_train.shape)
  print('X_test:',X_test.shape)
  print('y_train:', y_train.shape)
  print('y_test:',y_test.shape)

  index_for_method = 0 # initialize

  for name, reg_model in zip(names, regressors):
      print('\nRegression model evaluation for:', name)
      print(' Scikit Learn method:', reg_model)
      reg_model.fit(X_train, y_train) # fit on the train set for this fold

      print('Fitted regression intercept:', reg_model.intercept_)
      print('Fitted regression coefficients:', reg_model.coef_)

      intercept_results[index_for_fold, index_for_method]=reg_model.intercept_
      coef_results[index_for_fold, :, index_for_method]=reg_model.coef_[:]

      # evaluate on the test set for this fold
      y_test_predict = reg_model.predict(X_test)
      
      r2_result = r2_score(y_test, y_test_predict)

      fold_method_result = sqrt(mean_squared_error(y_test, y_test_predict))

      print(reg_model.get_params(deep=True))
      print('Root mean-squared error:', fold_method_result)
      
      rsquare_results[index_for_fold, index_for_method] =r2_result

      cv_results[index_for_fold, index_for_method] = fold_method_result
      index_for_method += 1

  index_for_fold += 1
# Out:
# Fold index: 0 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: 0.0016135906928882518
# Fitted regression coefficients: [-0.22453751  0.08125557  0.03118109  0.06662802 -0.22830667  0.1311516
#   0.02560665 -0.28078222  0.27515068 -0.2682453  -0.17921273 -0.55544419]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.2957195904826947
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: 0.0018266239033659856
# Fitted regression coefficients: [-0.22341147  0.07935222  0.02801944  0.06704416 -0.22531935  0.13307692
#   0.02467436 -0.2778277   0.26643188 -0.26034435 -0.1781853  -0.55250071]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.2951112840301624
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.013060673741497223
# Fitted regression coefficients: [-0.12165224  0.         -0.          0.00393107 -0.          0.14451854
#  -0.         -0.         -0.         -0.04832399 -0.09565938 -0.51201072]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.3220857420288324
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.013767835451315345
# Fitted regression coefficients: [-0.14501515  0.         -0.          0.0409552  -0.0088081   0.17975848
#   0.         -0.00801084 -0.         -0.07496835 -0.11567937 -0.47655932]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.3135510808714884
#
# Fold index: 1 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: 0.01208808692381462
# Fitted regression coefficients: [-0.22839479  0.08204614  0.05966741  0.06273351 -0.26703179  0.11623889
#   0.02287749 -0.28746627  0.30558921 -0.29288508 -0.2045527  -0.55170927]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.3557362987584146
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: 0.012072095926395104
# Fitted regression coefficients: [-0.22711804  0.07996187  0.05574722  0.06328462 -0.26356574  0.11839057
#   0.02129177 -0.28492506  0.29534047 -0.2830573  -0.20338701 -0.54892624]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.3533939236562825
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.008542099140003721
# Fitted regression coefficients: [-0.12045749  0.         -0.          0.00348272 -0.          0.12781332
#  -0.         -0.         -0.         -0.03133411 -0.12045913 -0.52648292]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.2872794163014753
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.00993066392775184
# Fitted regression coefficients: [-0.1430384   0.         -0.          0.04246593 -0.02798144  0.16532961
#  -0.         -0.0093179  -0.         -0.05059138 -0.1389374  -0.48607369]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.27921963841201985
#
# Fold index: 2 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: -0.0285015352336603
# Fitted regression coefficients: [-0.21720068  0.04064312 -0.03502924  0.08370979 -0.30202243  0.12573231
#   0.04730543 -0.26545079  0.33318122 -0.20775315 -0.20460055 -0.59199157]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.5090599995431104
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: -0.028101119077936547
# Fitted regression coefficients: [-0.21609677  0.03927731 -0.03858417  0.08416178 -0.29678237  0.12778992
#   0.04524879 -0.2630017   0.3222396  -0.19858192 -0.20335351 -0.588753  ]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.505277177047064
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.007183514615297357
# Fitted regression coefficients: [-0.11341963  0.         -0.          0.01309945 -0.          0.13879127
#  -0.         -0.         -0.         -0.00390701 -0.12508864 -0.55370464]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.34386373299140577
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.0063907966255910345
# Fitted regression coefficients: [-0.13637955  0.         -0.          0.05312101 -0.01022311  0.17746427
#  -0.         -0.00109203 -0.         -0.03375651 -0.14277344 -0.50847569]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.3356351274891151
#
# Fold index: 3 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: -0.007185399877012957
# Fitted regression coefficients: [-0.2268825   0.05903284  0.04901717  0.07716757 -0.21268637  0.1061088
#   0.02703844 -0.23992604  0.28333166 -0.27233593 -0.20410827 -0.54864164]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.4245560044773553
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: -0.007295944919205613
# Fitted regression coefficients: [-0.22573448  0.05771966  0.04565186  0.07778658 -0.2092429   0.1082081
#   0.02508008 -0.237617    0.27407618 -0.26360421 -0.202806   -0.54563133]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.4247130974719131
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.028462944349163813
# Fitted regression coefficients: [-0.12637024  0.         -0.          0.01476468 -0.          0.10460895
#  -0.         -0.         -0.         -0.02445838 -0.10411658 -0.50856142]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.570869982006579
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.022211739145993878
# Fitted regression coefficients: [-0.14764191  0.         -0.          0.0572284  -0.          0.14549148
#  -0.         -0.         -0.         -0.05028563 -0.12713356 -0.4776529 ]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.5326628081338625
#
# Fold index: 4 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: -0.01488846321704957
# Fitted regression coefficients: [-0.22266835  0.09818866  0.0262859   0.0810773  -0.24209919  0.09483232
#   0.07400697 -0.27482462  0.28116368 -0.25292204 -0.20028808 -0.5843725 ]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.4644772466725289
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: -0.014997141712747637
# Fitted regression coefficients: [-0.22148502  0.09637474  0.02349359  0.08133079 -0.23860323  0.09705881
#   0.07183125 -0.27213305  0.27231265 -0.24489186 -0.19912951 -0.58128198]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.4629341209714689
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.03220311373484333
# Fitted regression coefficients: [-0.11426857  0.         -0.          0.         -0.          0.10107414
#  -0.         -0.         -0.         -0.         -0.12099353 -0.56081968]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.5417237970167682
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.025683359296308966
# Fitted regression coefficients: [-1.38724777e-01  0.00000000e+00 -0.00000000e+00  2.19420502e-02
#  -1.05439468e-04  1.48976074e-01 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -3.14331031e-02 -1.38603764e-01 -5.18449641e-01]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.48010564651726634
#
# Fold index: 5 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (455, 12)
# X_test: (51, 12)
# y_train: (455,)
# y_test: (51,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: 0.006365256955278412
# Fitted regression coefficients: [-0.22551328  0.08990979  0.06252643  0.08174638 -0.26105619  0.11164796
#   0.01390876 -0.26334425  0.29188367 -0.2754438  -0.18494424 -0.54708859]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.34043009386943224
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: 0.00593668373963252
# Fitted regression coefficients: [-0.22427608  0.08755177  0.05909637  0.08213689 -0.25763711  0.11353453
#   0.01275052 -0.26013828  0.28204719 -0.26594243 -0.18379582 -0.54444751]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.33935592038142515
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.031612586543150425
# Fitted regression coefficients: [-0.13155267  0.         -0.          0.         -0.          0.08827692
#  -0.         -0.         -0.         -0.0123755  -0.07673354 -0.54082568]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.5390255201821031
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.020595916818358054
# Fitted regression coefficients: [-0.15072123  0.         -0.          0.04528647 -0.04289031  0.13655854
#  -0.         -0.         -0.         -0.02411936 -0.10954708 -0.48822319]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.45135967797087667
#
# Fold index: 6 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (456, 12)
# X_test: (50, 12)
# y_train: (456,)
# y_test: (50,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: 0.011633737623933573
# Fitted regression coefficients: [-0.22683205  0.05656621  0.02386158  0.06234488 -0.23576689  0.12538805
#   0.01200207 -0.29370726  0.28679064 -0.28112039 -0.19467477 -0.54951356]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.32213798129887583
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: 0.01197597933147622
# Fitted regression coefficients: [-0.22544012  0.05430011  0.0201503   0.06291291 -0.23211586  0.12731078
#   0.01064289 -0.28961149  0.27607373 -0.2705317  -0.19368307 -0.54696723]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.3208411154730994
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.03074691169976813
# Fitted regression coefficients: [-0.12006102  0.         -0.          0.         -0.          0.12069407
#  -0.         -0.         -0.         -0.04163393 -0.10477197 -0.54625141]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.4112183782182908
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.029667068547795775
# Fitted regression coefficients: [-0.14373753  0.         -0.          0.03767679 -0.01673735  0.16064277
#  -0.         -0.         -0.         -0.06005329 -0.12467909 -0.5033395 ]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.394552178304764
#
# Fold index: 7 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (456, 12)
# X_test: (50, 12)
# y_train: (456,)
# y_test: (50,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: -0.014429891716253362
# Fitted regression coefficients: [-0.14867649  0.03426603  0.04969662  0.02721119 -0.21473628  0.31345895
#  -0.05263717 -0.22373269  0.17100301 -0.26948884 -0.18485334 -0.33938759]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 1.0808231208606516
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: -0.014421775431262523
# Fitted regression coefficients: [-0.14694875  0.03310685  0.04692129  0.02764919 -0.21219695  0.3142431
#  -0.05319371 -0.22162316  0.16381046 -0.26289851 -0.18407225 -0.33807337]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 1.0827906106205776
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.010470404605955802
# Fitted regression coefficients: [-0.          0.         -0.          0.         -0.          0.2832298
#  -0.          0.         -0.         -0.13773836 -0.10549226 -0.35268861]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 1.1901685515127212
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.002449169934851503
# Fitted regression coefficients: [-0.03366823  0.         -0.          0.         -0.04302628  0.3084656
#  -0.         -0.         -0.         -0.14011882 -0.13618551 -0.32574266]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 1.179513221511315
#
# Fold index: 8 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (456, 12)
# X_test: (50, 12)
# y_train: (456,)
# y_test: (50,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: 0.024709652840434207
# Fitted regression coefficients: [-0.2918608   0.06397793  0.03652298  0.05579921 -0.1647806   0.21552541
#  -0.02397892 -0.24241881  0.32878197 -0.26754904 -0.16985876 -0.47857538]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.7523122168249469
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: 0.024729238581716717
# Fitted regression coefficients: [-0.2897625   0.06242408  0.03347626  0.05631597 -0.16224772  0.2169526
#  -0.02488941 -0.24016245  0.31928202 -0.25898015 -0.16901069 -0.4765097 ]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.7521139114041338
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.044845354591389164
# Fitted regression coefficients: [-0.11067277  0.         -0.          0.         -0.          0.22573807
#  -0.         -0.         -0.         -0.         -0.09258431 -0.45085472]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.8171018817101936
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: 0.034358458898270605
# Fitted regression coefficients: [-0.15997122  0.         -0.          0.03303296 -0.          0.25009971
#  -0.         -0.          0.         -0.01163282 -0.11458246 -0.43451912]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.7817808138820171
#
# Fold index: 9 ------------------------------------------
#
# Shape of input data for this fold:
# Data Set: (Observations, Variables)
# X_train: (456, 12)
# X_test: (50, 12)
# y_train: (456,)
# y_test: (50,)
#
# Regression model evaluation for: Linear_Regression
#  Scikit Learn method: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Fitted regression intercept: -0.014554328018661515
# Fitted regression coefficients: [-0.21147762  0.08630718  0.03227056  0.07021983 -0.22740967  0.14467315
#   0.05720537 -0.25928176  0.23858501 -0.27267561 -0.18235999 -0.53626874]
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# Root mean-squared error: 0.4192702311224106
#
# Regression model evaluation for: Ridge_Regression
#  Scikit Learn method: Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='cholesky', tol=0.001)
# Fitted regression intercept: -0.014498624488607142
# Fitted regression coefficients: [-0.21033892  0.08474576  0.0292931   0.07071785 -0.22457596  0.14652539
#   0.05548757 -0.25738945  0.22756562 -0.26264342 -0.18130223 -0.53338695]
# {'alpha': 1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': False, 'random_state': 1, 'solver': 'cholesky', 'tol': 0.001}
# Root mean-squared error: 0.42039528131463105
#
# Regression model evaluation for: Lasso_Regression
#  Scikit Learn method: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.0036289747614882545
# Fitted regression coefficients: [-0.12767151  0.         -0.          0.00620083 -0.          0.15260699
#  -0.         -0.         -0.         -0.03683822 -0.11418299 -0.49972322]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.42071782791042467
#
# Regression model evaluation for: Elastic_Net_Regression
#  Scikit Learn method: ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=1, selection='cyclic', tol=0.01, warm_start=False)
# Fitted regression intercept: -0.011417119273430774
# Fitted regression coefficients: [-0.14264307  0.         -0.          0.04533199 -0.00852056  0.18808035
#   0.         -0.00999621 -0.         -0.0810778  -0.13232882 -0.46504215]
# {'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 10000, 'normalize': False, 'positive': False, 'precompute': False, 'random_state': 1, 'selection': 'cyclic', 'tol': 0.01, 'warm_start': False}
# Root mean-squared error: 0.4401673978347141

# %%
cv_results_df = pd.DataFrame(cv_results)
cv_results_df.columns = names
print(cv_results_df.mean())
# Out:
# Linear_Regression         0.496452
# Ridge_Regression          0.495693
# Lasso_Regression          0.544405
# Elastic_Net_Regression    0.518855
# dtype: float64

# %% [markdown]
# **Note: I tried the same code above on raw response variables, the results  are listed below. As we can see, the predict error is higher than log transfrom version**
#
# Linear_Regression 0.561940
#
# Ridge_Regression 0.560511
#
# Lasso_Regression 0.587381
#
# Elastic_Net_Regression 0.568084

# %%
r2_results_df = pd.DataFrame(rsquare_results)
r2_results_df.columns = names
print(r2_results_df.mean())
# Out:
# Linear_Regression         0.374328
# Ridge_Regression          0.378451
# Lasso_Regression          0.339908
# Elastic_Net_Regression    0.404225
# dtype: float64

# %%
intercept_results_df=pd.DataFrame(intercept_results)
intercept_results_df.columns=names
print(intercept_results_df.mean())
# Out:
# Linear_Regression        -0.002315
# Ridge_Regression         -0.002277
# Lasso_Regression          0.000457
# Elastic_Net_Regression   -0.000102
# dtype: float64

# %%
coef_results_df=pd.DataFrame(np.mean(coef_results,axis=0))
coef_results_df.columns=names
coef_results_df.index=variables
print(coef_results_df)
# Out:
#          Linear_Regression  Ridge_Regression  Lasso_Regression  \
# crim             -0.222404         -0.221061         -0.108613
# zn                0.069219          0.067481          0.000000
# indus             0.033600          0.030327          0.000000
# chas              0.066864          0.067334          0.004148
# nox              -0.235590         -0.232229          0.000000
# romms             0.148476          0.150309          0.148735
# age               0.020334          0.018892          0.000000
# dis              -0.263093         -0.260443          0.000000
# rad               0.279546          0.269918          0.000000
# tax              -0.266042         -0.257148         -0.033661
# ptratio          -0.190945         -0.189873         -0.106008
# lstat            -0.528299         -0.525648         -0.505192
#
#          Elastic_Net_Regression
# crim                  -0.134154
# zn                     0.000000
# indus                  0.000000
# chas                   0.037704
# nox                   -0.015829
# romms                  0.186087
# age                    0.000000
# dis                   -0.002842
# rad                    0.000000
# tax                   -0.055804
# ptratio               -0.128045
# lstat                 -0.468408
